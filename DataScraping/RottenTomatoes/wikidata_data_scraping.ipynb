# %% [markdown]
# # Rotten Tomatoes Data Scraping

# %%
import os
while os.path.basename(os.getcwd()) != "ada-project-private":
    os.chdir('..')

import pandas as pd
import json

DATA_FOLDER = './MovieSummaries/'

# Load character.metadata.tsv
character_metadata_cols = ["Wikipedia movie ID", "Freebase movie ID",
                           "Movie release date", "Character name",
                           "Actor date of birth", "Actor gender", "Actor height (in meters)", "Actor ethnicity (Freebase ID)",
                           "Actor name", "Actor age at movie release",
                           "Freebase character/actor map ID", "Freebase character ID", "Freebase actor ID"]
character_metadata_df = pd.read_csv(DATA_FOLDER + 'character.metadata.tsv', sep='\t', header=None, names=character_metadata_cols)

# Load movie.metadata.tsv
movie_metadata_cols = ["Wikipedia movie ID", "Freebase movie ID", "Movie name", "Movie release date", "Movie box office revenue", "Movie runtime",
                       "Movie languages (Freebase ID:name tuples)", "Movie countries (Freebase ID:name tuples)",
                       "Movie genres (Freebase ID:name tuples)"]
movie_metadata_df = pd.read_csv(DATA_FOLDER + 'movie.metadata.tsv', sep='\t', header=None, names=movie_metadata_cols)

# Load name.clusters.txt
name_clusters_cols = ["Character name", "Freebase movie ID"]
name_clusters_df = pd.read_csv(DATA_FOLDER + 'name.clusters.txt', sep='\t', header=None, names=name_clusters_cols)

# Load plot_summaries.txt
plot_summaries_cols = ["Wikipedia movie ID", "Wikipedia plot"]
plot_summaries_df = pd.read_csv(DATA_FOLDER + 'plot_summaries.txt', sep='\t', header=None, names=plot_summaries_cols)

# Load tvtropes.clusters.txt
tvtropes_clusters_cols = ["Character types", "details"]
tvtropes_clusters_df = pd.read_csv(DATA_FOLDER + 'tvtropes.clusters.txt', sep='\t', header=None, names=tvtropes_clusters_cols)

tvtropes_clusters_df["details_dict"] = tvtropes_clusters_df["details"].apply(json.loads)
tvtropes_clusters_df["Character name"] = tvtropes_clusters_df["details_dict"].apply(lambda x: x.get('char'))
tvtropes_clusters_df["Movie name"] = tvtropes_clusters_df["details_dict"].apply(lambda x: x.get('movie'))
tvtropes_clusters_df["Freebase character/actor map ID"] = tvtropes_clusters_df["details_dict"].apply(lambda x: x.get('id'))
tvtropes_clusters_df["Actor name"] = tvtropes_clusters_df["details_dict"].apply(lambda x: x.get('actor'))

tvtropes_clusters_df.drop(columns=["details", "details_dict"], inplace=True)



CURRENT_PATH = "DataScraping/RottenTomatoes/"

# %%
import numpy as np

def set_counter(n, name = "default"):
	np.save(CURRENT_PATH + "counters/counter_" + name + ".npy", np.array(int(n), dtype=int))

def get_counter(name = "default"):
	return np.load(CURRENT_PATH + "counters/counter_" + name + ".npy")

def add_counter(n, name = "default"):
	set_counter(get_counter(name) + n, name)

def safe_int_conversion(value, default):
    try:
        return int(value)
    except ValueError:
        return default

# %%
from fuzzywuzzy import fuzz

def names_similarity(str1, str2):
    return fuzz.ratio(str1.lower().replace(' ','').replace('\'',''), str2.lower().replace(' ','').replace('\'',''))/100.

def time_to_minutes(time_string):
    hours = 0
    minutes = 0
    
    time_parts = time_string.split()

    for part in time_parts:
        if 'h' in part:
            hours = int(part.replace('h', ''))
        if 'm' in part:
            minutes = int(part.replace('m', ''))

    total_minutes = hours * 60 + minutes
    return total_minutes

def safe_int_conversion(value, default):
    try:
        return int(value)
    except ValueError:
        return default

# %%
import requests
from bs4 import BeautifulSoup

def get_rotten_url_from_movie_name(movie_name, year = None, toll = 0.8):
    r = requests.get("https://www.rottentomatoes.com/search?search=" + requests.utils.quote(movie_name, safe=''))
    soup = BeautifulSoup(r.content, 'html.parser')
    movies = soup.find_all('search-page-media-row')
    movie_list = []
    
    for movie in movies:
        title_tag = movie.find('a', {'slot': 'title'})
        title = title_tag.get_text(strip=True) if title_tag else ''
        
        release_year = safe_int_conversion(movie.get('releaseyear', ''), None)
        
        link = title_tag.get('href') if title_tag else ''
        
        movie_list.append((title, release_year, link))

    best_match = dict()
    best_match['toll'] = toll
    best_match['movie'] = (None, None, None)
    for movie in movie_list:
        similarity = names_similarity(movie[0], movie_name)
        if similarity > best_match['toll'] and (year is None or movie[1] is None or abs(movie[1] - year) <= 1):
            best_match['toll'] = similarity
            best_match['movie'] = movie
    return best_match['movie'][2]

def get_rotten_movie_metadata(url, toll = 0.95):
    if url is None:
        return None
    
    movie_metadata = dict()
    
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    movie_metadata["title"] = soup.find('rt-text', {'slot': 'title'}).get_text(strip=True)
    
    critics_score_string = soup.find('rt-button', {'slot': 'criticsScore'}).find('rt-text').get_text(strip=True).replace("%","")
    movie_metadata["critics_score"] = safe_int_conversion(critics_score_string, None)
    audience_score_string = soup.find('rt-button', {'slot': 'audienceScore'}).find('rt-text').get_text(strip=True).replace("%","")
    movie_metadata["audience_score"] = safe_int_conversion(audience_score_string, None)
    
    category_wraps = soup.find_all('div', {'class': 'category-wrap', 'data-qa': 'item'})
    for wrap in category_wraps:
        wrap_title = wrap.find('rt-text', {'class': 'key'}).get_text(strip=True)
        
        if names_similarity(wrap_title, "Rating") > toll:
            movie_metadata["rating"] = wrap.find(['rt-text', 'rt-link'], {'data-qa': 'item-value'}).get_text(strip=True)
        if names_similarity(wrap_title, "Genre") > toll:
            movie_metadata["genre"] = wrap.find(['rt-text', 'rt-link'], {'data-qa': 'item-value'}).get_text(strip=True)
        if names_similarity(wrap_title, "Original Language") > toll:
            movie_metadata["language"] = wrap.find(['rt-text', 'rt-link'], {'data-qa': 'item-value'}).get_text(strip=True)
        if names_similarity(wrap_title, "Runtime") > toll:
            runtime_string = wrap.find(['rt-text', 'rt-link'], {'data-qa': 'item-value'}).get_text(strip=True)
            movie_metadata["runtime"] = time_to_minutes(runtime_string)
    
    return movie_metadata

def scrape_row(i):
    row = movie_metadata_df.iloc[i]

    movie_title = row["Movie name"]
    year = None if pd.isna(row["Movie release date"]) else safe_int_conversion(row["Movie release date"].split('-')[0], None)

    scraped_dict = get_rotten_movie_metadata(get_rotten_url_from_movie_name(movie_title, year))

    if scraped_dict:
        scraped_dict["freebaseID"] = row["Freebase movie ID"]
        scraped_dict["original_title"] = row["Movie name"]
        scraped_dict["year"] = year

    return scraped_dict

# %%
set_counter(0, name = "low")

# %%
scraped_data_list = []

n = len(movie_metadata_df)
step = 100

low = get_counter(name = "low")
while low < n:
    up = min(low + step, n)
    set_counter(up, name = "low")

    print(f"starting new batch {low} - {up}")
    
    scraped_data_list = []
    
    for i in range(low, up):
        scraped_dict = scrape_row(i)

        if scraped_dict is not None:
            scraped_data_list.append(scraped_dict)

        print(f"processed {i} - {i-low+1}/{step}")
    
    c = int(low // step + 1)
    pd.DataFrame(scraped_data_list).to_csv(CURRENT_PATH + f"Data/tempData/rotten_movie_data_{c:05d}.csv", index=False)

    low = get_counter(name = "low")
# Out:
# starting new batch 0 - 100
# processed 0 - 0/100
# processed 1 - 1/100
# processed 2 - 2/100
# processed 3 - 3/100
# processed 4 - 4/100
# processed 5 - 5/100
# processed 6 - 6/100
# processed 7 - 7/100
# processed 8 - 8/100
# processed 9 - 9/100
# processed 10 - 10/100
# processed 11 - 11/100
# processed 12 - 12/100
# processed 13 - 13/100
# processed 14 - 14/100
# processed 15 - 15/100
# processed 16 - 16/100
# processed 17 - 17/100
# processed 18 - 18/100
# processed 19 - 19/100
# processed 20 - 20/100
# processed 21 - 21/100
# processed 22 - 22/100
# processed 23 - 23/100
# processed 24 - 24/100
# processed 25 - 25/100
# processed 26 - 26/100
# processed 27 - 27/100
# processed 28 - 28/100
# processed 29 - 29/100
# processed 30 - 30/100
# processed 31 - 31/100
# processed 32 - 32/100
# processed 33 - 33/100
# processed 34 - 34/100
# processed 35 - 35/100
# processed 36 - 36/100
# processed 37 - 37/100
# processed 38 - 38/100
# processed 39 - 39/100
# processed 40 - 40/100
# processed 41 - 41/100
# processed 42 - 42/100
# processed 43 - 43/100
# processed 44 - 44/100
# processed 45 - 45/100
# processed 46 - 46/100
# processed 47 - 47/100
# processed 48 - 48/100
# processed 49 - 49/100
# processed 50 - 50/100
# processed 51 - 51/100
# processed 52 - 52/100
# processed 53 - 53/100
# processed 54 - 54/100
# processed 55 - 55/100
# processed 56 - 56/100
# processed 57 - 57/100
# processed 58 - 58/100
# processed 59 - 59/100
# processed 60 - 60/100
# processed 61 - 61/100
# processed 62 - 62/100
# processed 63 - 63/100
# processed 64 - 64/100
# processed 65 - 65/100
# processed 66 - 66/100
# processed 67 - 67/100
# processed 68 - 68/100
# processed 69 - 69/100
# processed 70 - 70/100
# processed 71 - 71/100
# processed 72 - 72/100
# processed 73 - 73/100
# processed 74 - 74/100
# processed 75 - 75/100
# processed 76 - 76/100
# processed 77 - 77/100
# processed 78 - 78/100
# processed 79 - 79/100
# processed 80 - 80/100
# processed 81 - 81/100
# processed 82 - 82/100
# processed 83 - 83/100
# processed 84 - 84/100
# processed 85 - 85/100
# processed 86 - 86/100
# processed 87 - 87/100
# processed 88 - 88/100
# processed 89 - 89/100
# processed 90 - 90/100
# processed 91 - 91/100
# processed 92 - 92/100
# processed 93 - 93/100
# processed 94 - 94/100
# processed 95 - 95/100
# processed 96 - 96/100
# processed 97 - 97/100
# processed 98 - 98/100
# processed 99 - 99/100
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 24
#      21     print(f"processed {i} - {i-low}/{step}")
#      23 c = int(low // step + 1)
# ---> 24 pd.DataFrame(scraped_data_list).to_csv(CURRENT_PATH + f"Data/tempData/rotten_movie_data_{c:05d}.csv", index=False)
#      26 low = get_counter(name = "low")
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\OneDrive\Anno V\1 - Applied Data Analysis\ADA_env\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'DataScraping\RottenTomatoes\Data\tempData'

# %%
scraped_data_list
# Out:
# [{'title': 'White of the Eye',
#   'critics_score': 50,
#   'audience_score': 57,
#   'rating': 'R',
#   'genre': 'Mystery & Thriller',
#   'language': 'English',
#   'runtime': 110,
#   'freebaseID': '/m/0285_cd',
#   'original_title': 'White Of The Eye',
#   'year': 1987},
#  {'title': 'A Woman in Flames',
#   'critics_score': None,
#   'audience_score': 62,
#   'genre': 'Drama',
#   'language': 'German',
#   'runtime': 107,
#   'freebaseID': '/m/01mrr1',
#   'original_title': 'A Woman in Flames',
#   'year': 1983},
#  {'title': "The Sorcerer's Apprentice",
#   'critics_score': None,
#   'audience_score': 32,
#   'genre': 'Fantasy',
#   'language': 'English',
#   'runtime': 89,
#   'freebaseID': '/m/04jcqvw',
#   'original_title': "The Sorcerer's Apprentice",
#   'year': 2002},
#  {'title': "Alexander's Ragtime Band",
#   'critics_score': 83,
#   'audience_score': 46,
#   'genre': 'Musical',
#   'language': 'English',
#   'runtime': 105,
#   'freebaseID': '/m/02qc0j7',
#   'original_title': "Alexander's Ragtime Band",
#   'year': 1938},
#  {'title': 'Sarah and Son',
#   'critics_score': None,
#   'audience_score': 22,
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 86,
#   'freebaseID': '/m/017n1p',
#   'original_title': 'Sarah and Son',
#   'year': 1930},
#  {'title': 'Lady Snowblood 2: Love Song of Vengeance',
#   'critics_score': None,
#   'audience_score': 59,
#   'genre': 'Drama',
#   'language': 'Japanese',
#   'runtime': 89,
#   'freebaseID': '/m/07kjkz6',
#   'original_title': 'Lady Snowblood 2: Love Song of Vengeance',
#   'year': 1974},
#  {'title': 'Little City',
#   'critics_score': None,
#   'audience_score': 64,
#   'rating': 'R',
#   'genre': 'Romance',
#   'language': 'English',
#   'runtime': 89,
#   'freebaseID': '/m/0gffwj',
#   'original_title': 'Little city',
#   'year': 1997},
#  {'title': 'Henry V',
#   'critics_score': 98,
#   'audience_score': 89,
#   'rating': 'PG-13 (A Bloody Battle)',
#   'genre': 'History',
#   'language': 'English',
#   'runtime': 137,
#   'freebaseID': '/m/016ywb',
#   'original_title': 'Henry V',
#   'year': 1989},
#  {'title': 'The Mechanical Universe',
#   'critics_score': None,
#   'audience_score': None,
#   'rating': 'TV-G',
#   'genre': 'Special Interest',
#   'language': 'English',
#   'freebaseID': '/m/02r52hc',
#   'original_title': 'The Mechanical Monsters',
#   'year': None},
#  {'title': '1919',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 99,
#   'freebaseID': '/m/0g5qvzg',
#   'original_title': '1919',
#   'year': 1984},
#  {'title': 'Mary Poppins',
#   'critics_score': 97,
#   'audience_score': 86,
#   'rating': 'G',
#   'genre': 'Kids & Family',
#   'language': 'English',
#   'runtime': 140,
#   'freebaseID': '/m/0kcn7',
#   'original_title': 'Mary Poppins',
#   'year': 1964},
#  {'title': 'Keep the Change',
#   'critics_score': None,
#   'audience_score': 60,
#   'rating': 'TV-PG',
#   'genre': 'Western',
#   'language': 'English',
#   'runtime': 100,
#   'freebaseID': '/m/0gj30jx',
#   'original_title': 'Keep the Change',
#   'year': 1992},
#  {'title': "The Devil's Holiday",
#   'critics_score': None,
#   'audience_score': 25,
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 80,
#   'freebaseID': '/m/017n1b',
#   'original_title': "The Devil's Holiday",
#   'year': 1930},
#  {'title': 'New Rose Hotel',
#   'critics_score': 24,
#   'audience_score': 38,
#   'rating': 'R',
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 92,
#   'freebaseID': '/m/02wjqm',
#   'original_title': 'New Rose Hotel',
#   'year': 1999},
#  {'title': 'White on Rice',
#   'critics_score': 45,
#   'audience_score': 52,
#   'rating': 'PG-13 (Sex-Related Humor|Some Violent Images)',
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 90,
#   'freebaseID': '/m/05p45cv',
#   'original_title': 'White on Rice',
#   'year': 2009},
#  {'title': 'Road to Life',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'Russian',
#   'runtime': 98,
#   'freebaseID': '/m/0g4_n3m',
#   'original_title': 'Road to Life',
#   'year': 1931},
#  {'title': 'Camera Thrills',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Documentary',
#   'language': 'English',
#   'runtime': 25,
#   'freebaseID': '/m/047t9rb',
#   'original_title': 'Camera Thrills',
#   'year': 1935},
#  {'title': 'Middle Age Spread',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 94,
#   'freebaseID': '/m/05f5_5y',
#   'original_title': 'Middle Age Spread',
#   'year': 1979},
#  {'title': 'Baby Boy',
#   'critics_score': 71,
#   'audience_score': 87,
#   'rating': 'R (Some Drug Use|Language|Strong Sexuality|Violence)',
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 129,
#   'freebaseID': '/m/014k4y',
#   'original_title': 'Baby Boy',
#   'year': 2001},
#  {'title': 'Bindiya Chamkegi',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Comedy',
#   'language': 'Hindi',
#   'runtime': 139,
#   'freebaseID': '/m/02rc_h4',
#   'original_title': 'Bindiya Chamkegi',
#   'year': 1984},
#  {'title': 'Vandhanam',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Romance',
#   'language': 'Malayalam',
#   'runtime': 179,
#   'freebaseID': '/m/02pml15',
#   'original_title': 'Vandanam',
#   'year': 1989},
#  {'title': 'Special Effects',
#   'critics_score': None,
#   'audience_score': None,
#   'rating': 'R',
#   'genre': 'Mystery & Thriller',
#   'language': 'English',
#   'runtime': 93,
#   'freebaseID': '/m/04j284s',
#   'original_title': 'Special Effects',
#   'year': 1984},
#  {'title': 'Anokha Rishta',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'Hindi',
#   'freebaseID': '/m/04j0lfk',
#   'original_title': 'Anokha Rishta',
#   'year': 1986},
#  {'title': 'They Knew What They Wanted',
#   'critics_score': None,
#   'audience_score': 40,
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 96,
#   'freebaseID': '/m/04wy0v',
#   'original_title': 'They Knew What They Wanted',
#   'year': 1940},
#  {'title': 'Siam Sunset',
#   'critics_score': 67,
#   'audience_score': 60,
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 91,
#   'freebaseID': '/m/0b6c_nw',
#   'original_title': 'Siam Sunset',
#   'year': 1999},
#  {'title': 'Kausthubham',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'Malayalam',
#   'runtime': 180,
#   'freebaseID': '/m/0bh9fbk',
#   'original_title': 'Kausthubham',
#   'year': 2010},
#  {'title': 'Archie: To Riverdale and Back Again',
#   'critics_score': None,
#   'audience_score': 44,
#   'rating': 'PG',
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 96,
#   'freebaseID': '/m/02pjlrp',
#   'original_title': 'Archie: To Riverdale and Back Again',
#   'year': 1990},
#  {'title': 'Mysterious Islands',
#   'critics_score': None,
#   'audience_score': None,
#   'rating': 'TV-G',
#   'genre': 'Travel',
#   'language': 'English',
#   'freebaseID': '/m/0f400r',
#   'original_title': 'Mysterious Island',
#   'year': 1982},
#  {'title': 'Electric Apricot: Quest for Festeroo',
#   'critics_score': None,
#   'audience_score': 72,
#   'rating': 'R (Language|Some Sexual Content Incl Ref)',
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 91,
#   'freebaseID': '/m/0734w5',
#   'original_title': 'Electric Apricot: Quest For Festeroo',
#   'year': 2006},
#  {'title': 'Troopers',
#   'critics_score': None,
#   'audience_score': None,
#   'rating': 'TV-14',
#   'genre': 'Documentary',
#   'language': 'English',
#   'freebaseID': '/m/07h9zj',
#   'original_title': 'Troops',
#   'year': 1997},
#  {'title': 'Daddy and Them',
#   'critics_score': 86,
#   'audience_score': 54,
#   'rating': 'R (Strong Language)',
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 101,
#   'freebaseID': '/m/0b6kc_5',
#   'original_title': 'Daddy and Them',
#   'year': 2001},
#  {'title': 'The Gods Must Be Crazy',
#   'critics_score': 86,
#   'audience_score': 84,
#   'rating': 'PG',
#   'genre': 'Comedy',
#   'language': 'Afrikaans',
#   'runtime': 108,
#   'freebaseID': '/m/01mrrd',
#   'original_title': 'The Gods Must Be Crazy',
#   'year': 1980},
#  {'title': 'Joan the Woman',
#   'critics_score': None,
#   'audience_score': 38,
#   'genre': 'Adventure',
#   'runtime': 100,
#   'freebaseID': '/m/03grb4v',
#   'original_title': 'Joan the Woman',
#   'year': 1917},
#  {'title': 'Rudo y Cursi',
#   'critics_score': 73,
#   'audience_score': 66,
#   'rating': 'R (Pervasive Language|Brief Drug Use|Sexual Content)',
#   'genre': 'Comedy',
#   'language': 'Spanish',
#   'runtime': 103,
#   'freebaseID': '/m/02vlsqt',
#   'original_title': 'Rudo y Cursi',
#   'year': 2008},
#  {'title': 'Kinjite: Forbidden Subjects',
#   'critics_score': 0,
#   'audience_score': 35,
#   'rating': 'R',
#   'genre': 'Crime',
#   'language': 'English',
#   'runtime': 98,
#   'freebaseID': '/m/0cws46',
#   'original_title': 'Kinjite: Forbidden Subjects',
#   'year': 1989},
#  {'title': 'Jay Vejay',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Action',
#   'language': 'Hindi',
#   'runtime': 152,
#   'freebaseID': '/m/05b0lk8',
#   'original_title': 'Jay Vejay',
#   'year': 1977},
#  {'title': 'My Name Is Fame',
#   'critics_score': None,
#   'audience_score': 85,
#   'genre': 'Comedy',
#   'language': 'Chinese',
#   'runtime': 94,
#   'freebaseID': '/m/03c0d85',
#   'original_title': 'My Name is Fame',
#   'year': 2006},
#  {'title': 'Hamsun',
#   'critics_score': 100,
#   'audience_score': 92,
#   'genre': 'Biography',
#   'language': 'Danish',
#   'runtime': 158,
#   'freebaseID': '/m/05f6kpj',
#   'original_title': 'Hamsun',
#   'year': 1996},
#  {'title': 'The Great New Wonderful',
#   'critics_score': 73,
#   'audience_score': 45,
#   'rating': 'R (Some Sexuality|Language)',
#   'genre': 'Comedy',
#   'language': 'English',
#   'runtime': 87,
#   'freebaseID': '/m/0f0d1p',
#   'original_title': 'The Great New Wonderful',
#   'year': 2006},
#  {'title': 'Loverboy',
#   'critics_score': 50,
#   'audience_score': 56,
#   'rating': 'PG-13',
#   'genre': 'Romance',
#   'language': 'English',
#   'runtime': 98,
#   'freebaseID': '/m/02vn81r',
#   'original_title': 'Loverboy',
#   'year': 1989},
#  {'title': 'Chandra Mukhi',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Fantasy',
#   'language': 'Hindi',
#   'runtime': 180,
#   'freebaseID': '/m/0dll97s',
#   'original_title': 'Chandra Mukhi',
#   'year': 1993},
#  {'title': 'Juarez',
#   'critics_score': 71,
#   'audience_score': 49,
#   'genre': 'Biography',
#   'language': 'English',
#   'runtime': 132,
#   'freebaseID': '/m/04x8zs',
#   'original_title': 'Juarez',
#   'year': 1939},
#  {'title': 'Chasing Ghosts: Beyond the Arcade',
#   'critics_score': None,
#   'audience_score': 64,
#   'genre': 'Documentary',
#   'language': 'English',
#   'runtime': 91,
#   'freebaseID': '/m/02w1jsk',
#   'original_title': 'Chasing Ghosts: Beyond the Arcade',
#   'year': 2007},
#  {'title': 'It Came Upon the Midnight Clear',
#   'critics_score': None,
#   'audience_score': 86,
#   'genre': 'Holiday',
#   'language': 'English',
#   'runtime': 100,
#   'freebaseID': '/m/0g4zl4c',
#   'original_title': 'It Came Upon the Midnight Clear',
#   'year': 1984},
#  {'title': 'Vipers',
#   'critics_score': None,
#   'audience_score': 17,
#   'rating': 'R (Some Language|Sexual Content|Gore|Violence)',
#   'genre': 'Horror',
#   'language': 'English',
#   'runtime': 89,
#   'freebaseID': '/m/04zyc0t',
#   'original_title': 'Vipers',
#   'year': 2008},
#  {'title': 'Ivar',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Action',
#   'runtime': 180,
#   'freebaseID': '/m/0fdc85',
#   'original_title': 'Ivar',
#   'year': 2003},
#  {'title': 'The Human Tornado',
#   'critics_score': 80,
#   'audience_score': 69,
#   'rating': 'R',
#   'genre': 'Action',
#   'language': 'English',
#   'runtime': 85,
#   'freebaseID': '/m/07v6f3',
#   'original_title': 'The Human Tornado',
#   'year': 1976},
#  {'title': 'Shivers',
#   'critics_score': 85,
#   'audience_score': 58,
#   'rating': 'R',
#   'genre': 'Horror',
#   'language': 'English',
#   'runtime': 88,
#   'freebaseID': '/m/04mhwd',
#   'original_title': 'Shivers',
#   'year': 1975},
#  {'title': 'My Friend Ganesha',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'Hindi',
#   'runtime': 190,
#   'freebaseID': '/m/080bxrj',
#   'original_title': 'My Friend Ganesha',
#   'year': 2007},
#  {'title': 'The Tango Player',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'German',
#   'runtime': 96,
#   'freebaseID': '/m/0gj93w4',
#   'original_title': 'The Tango Player',
#   'year': 1991},
#  {'title': 'The Covered Wagon',
#   'critics_score': 91,
#   'audience_score': 50,
#   'genre': 'Western',
#   'runtime': 98,
#   'freebaseID': '/m/0kv612',
#   'original_title': 'The Covered Wagon',
#   'year': 1923},
#  {'title': 'Sombra Verde',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Drama',
#   'language': 'Spanish',
#   'runtime': 85,
#   'freebaseID': '/m/0crvlhb',
#   'original_title': 'Sombra Verde',
#   'year': 1954},
#  {'title': 'The Little Hut',
#   'critics_score': None,
#   'audience_score': 25,
#   'genre': 'Romance',
#   'language': 'English',
#   'runtime': 78,
#   'freebaseID': '/m/0h10pz',
#   'original_title': 'The Little Hut',
#   'year': 1957},
#  {'title': 'Nariman.',
#   'critics_score': None,
#   'audience_score': None,
#   'genre': 'Mystery & Thriller',
#   'language': 'Malayalam',
#   'runtime': 135,
#   'freebaseID': '/m/0gh8wn7',
#   'original_title': 'Nariman',
#   'year': 2001},
#  {'title': 'Drums in the Deep South',
#   'critics_score': None,
#   'audience_score': 22,
#   'genre': 'History',
#   'language': 'English',
#   'runtime': 87,
#   'freebaseID': '/m/04j1nd9',
#   'original_title': 'Drums in the Deep South',
#   'year': 1951},
#  {'title': 'Vixen',
#   'critics_score': None,
#   'audience_score': 37,
#   'rating': 'TV-PG',
#   'genre': 'Action',
#   'language': 'English',
#   'freebaseID': '/m/0dyy_v',
#   'original_title': 'Vixen!',
#   'year': 1968},
#  {'title': 'ZA: Zombies Anonymous',
#   'critics_score': None,
#   'audience_score': 49,
#   'genre': 'Horror',
#   'language': 'English',
#   'runtime': 118,
#   'freebaseID': '/m/0crx1wl',
#   'original_title': 'ZA: Zombies Anonymous',
#   'year': 2005},
#  {'title': 'Closing the Ring',
#   'critics_score': 32,
#   'audience_score': 59,
#   'rating': 'R (Nudity|Brief Sexuality|Violent Images)',
#   'genre': 'Drama',
#   'language': 'English',
#   'runtime': 119,
#   'freebaseID': '/m/0fc8w8',
#   'original_title': 'Closing the Ring',
#   'year': 2007},
#  {'title': 'The Boston Strangler',
#   'critics_score': 88,
#   'audience_score': 73,
#   'rating': 'R',
#   'genre': 'Crime',
#   'language': 'English',
#   'runtime': 116,
#   'freebaseID': '/m/02x4zpv',
#   'original_title': 'The Boston Strangler',
#   'year': 1968}]

# %%
pd.DataFrame(scraped_data_list).to_csv(CURRENT_PATH + f"Data/tempData/rotten_movie_data_{c:05d}.csv", index=False)
